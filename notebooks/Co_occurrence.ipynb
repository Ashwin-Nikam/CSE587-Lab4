# %%
library("twitteR")
consumer_key <- 'AnrGJtCP8a6LYcuvs3kT7BUA3'
consumer_secret <-'ClvivQ4KUBSRcLCgGvVsPaWa2KTboLbEU7CdDJZxr09bLmmh8r'
access_token <- '1246572168-mp0E4vgMd67RCsjRwLrTHgwquqxxTIGyaBrE3sW'
access_secret <- 'jltmB78vO2ZHqwMTfrH9p8nNvDQ7WKliVT8AU3FZPmUp4'
setup_twitter_oauth(consumer_key, consumer_secret, access_token, access_secret)
# Out:
# [1] "Using direct authentication"

# %%
query <- "#EPL"
tweets2 <- searchTwitter(query, n = 500, lang = "en")

# %%
tweets <- twListToDF(tweets2)
tweets.text <- tweets$text
tweets.text
# Out:
#   [1] "RT @ToughLoveSports: Game On! #EPL #CFC #ManU #ManCity #Tottenham #Liverpool https://t.co/UktrBWzzzB https://t.co/ohKjO8Jfhl"
#   [2] "RT @ToughLoveSports: Game On! #EPL #CFC #ManU #ManCity #Tottenham #Liverpool\n\nhttps://t.co/UktrBWzzzB https://t.co/qDBaN60Qpc"
#   [3] "Watford: we'll stick by hangover starlet, reports local press #EPL"
#   [4] "#Romero does not regret joining #ManUtd as #DeGea back-up @manUtd #football #Premierleague #EPL #Mourinho #followus https://t.co/rWxc6NhTZJ"
#   [5] "Rumor Roundup (April 25, 2016): Barcelona wants Leicester City star, Tottenham #PremierLeague #EPL #LeicesterCity… https://t.co/3moct8xNvy"
#   [6] "Arsenal confirm broken leg for Wilshere https://t.co/LUGWmqgfwD #EPL"
#   [7] "Win tickets to watch Bournemouth vs Middlesbrough courtesy of EA Sports https://t.co/FmRU7eJHk5 #EPL"
#   [8] "Why bringing in a Vieira figure at Arsenal won’t change a thing #epl @G1982112: The referee mistakes and Cristiano… https://t.co/6X3scVIWf6"
# ...

# %%
# Replace blank space (“rt”)
 tweets.text <- gsub("rt", "", tweets.text)

 # Replace @UserName
 tweets.text <- gsub("@\\w+", "", tweets.text)

 # Remove punctuation
 tweets.text <- gsub("[[:punct:]]", "", tweets.text)

 # Remove links
 tweets.text <- gsub("http\\w+", "", tweets.text)

 # Remove tabs
 tweets.text <- gsub("[ |\t]{2,}", "", tweets.text)

 # Remove blank spaces at the beginning
 tweets.text <- gsub("^ ", "", tweets.text)

# Remove blank spaces at the end
 tweets.text <- gsub(" $", "", tweets.text)

 # Remove blank spaces in the middle
 tweets.text <- gsub("\\s+", " ", tweets.text)

# %%
library("tm")

#create corpus
tweets.text.corpus <- Corpus(VectorSource(tweets.text))

#clean up by removing stop words
tweets.text.corpus <- tm_map(tweets.text.corpus, function(x)removeWords(x,stopwords()))

# %%
tweets.txt <- unique(tweets.text)
tweets.txt <- data.frame(tweets.txt)
tweets.txt
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# ...

# %%
nrow(tweets.txt)
# Out:
# [1] 285

# %%
write.table(tweets.txt,"co_occur5.txt",sep=",",row.names=FALSE, quote = FALSE)

# %% [markdown]
# http://technokarak.com/how-to-clean-the-twitter-data-using-r-twitter-mining-tutorial.html

# %% [markdown]
# # Data Prepared for Word Co-Occurence
# # ------------------------------------------------------------
